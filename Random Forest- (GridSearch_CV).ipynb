# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset [['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset [['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid= {'criterion': ['squared_error','friedman_mse','absolute_error','poisson'], 'max_features' : ['auto', 'sqrt', 'log2'], 'n_estimators': [10, 100, 200]}

# %%
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100, 200]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for the best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for the best parameter{'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 200}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.483595      0.158440         0.021873        0.012500
# 1        2.222700      0.108719         0.060171        0.018424
# 2        4.779285      0.239332         0.152023        0.026194
# 3        0.242644      0.026977         0.012506        0.006253
# 4        1.789709      0.081656         0.082256        0.011594
# 5        3.666339      0.112756         0.146744        0.033790
# 6        0.236613      0.031925         0.015625        0.009881
# 7        1.861564      0.022446         0.072180        0.021291
# 8        3.550543      0.143354         0.143750        0.025001
# 9        0.332355      0.029712         0.028736        0.023489
# 10       2.613753      0.372066         0.118489        0.062623
# 11       5.425888      0.271033         0.149016        0.027697
# 12       0.267073      0.030816         0.035889        0.024998
# 13       2.044370      0.144718         0.090852        0.006380
# 14       4.773052      0.361152         0.210536        0.045740
# 15       0.316405      0.039664         0.027784        0.020231
# 16       2.027010      0.082186         0.086626        0.022756
# 17       3.777527      0.130658         0.135067        0.029517
# 18       1.038587      0.034993         0.029679        0.027143
# 19       9.073958      0.072215         0.096150        0.016785
# 20      17.961377      0.396787         0.146376        0.024892
# 21       0.586555      0.023436         0.012503        0.006251
# 22       5.463882      0.145262         0.078130        0.024207
# 23      10.720747      0.042372         0.168752        0.006250
# 24       0.599892      0.036445         0.012501        0.006250
# 25       5.431512      0.130501         0.075002        0.041221
# 26      10.954041      0.244652         0.169854        0.013520
# 27       0.442389      0.034260         0.018029        0.015525
# 28       3.033451      0.259853         0.098428        0.055412
# 29       7.029984      0.146761         0.195650        0.023754
# 30       0.339013      0.035374         0.019756        0.023344
# 31       2.909203      0.162627         0.121903        0.035453
# 32       4.958016      0.473499         0.146874        0.027242
# 33       0.303128      0.045929         0.021875        0.021194
# 34       2.118752      0.062965         0.103125        0.018748
# 35       4.735783      0.326432         0.149576        0.035831
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 10
# 1    squared_error               auto                100
# 2    squared_error               auto                200
# 3    squared_error               sqrt                 10
# 4    squared_error               sqrt                100
# 5    squared_error               sqrt                200
# 6    squared_error               log2                 10
# 7    squared_error               log2                100
# 8    squared_error               log2                200
# 9     friedman_mse               auto                 10
# 10    friedman_mse               auto                100
# 11    friedman_mse               auto                200
# 12    friedman_mse               sqrt                 10
# 13    friedman_mse               sqrt                100
# 14    friedman_mse               sqrt                200
# 15    friedman_mse               log2                 10
# 16    friedman_mse               log2                100
# 17    friedman_mse               log2                200
# 18  absolute_error               auto                 10
# 19  absolute_error               auto                100
# 20  absolute_error               auto                200
# 21  absolute_error               sqrt                 10
# 22  absolute_error               sqrt                100
# 23  absolute_error               sqrt                200
# 24  absolute_error               log2                 10
# 25  absolute_error               log2                100
# 26  absolute_error               log2                200
# 27         poisson               auto                 10
# 28         poisson               auto                100
# 29         poisson               auto                200
# 30         poisson               sqrt                 10
# 31         poisson               sqrt                100
# 32         poisson               sqrt                200
# 33         poisson               log2                 10
# 34         poisson               log2                100
# 35         poisson               log2                200
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.838118
# 1   {'criterion': 'squared_error', 'max_features':...           0.847463
# 2   {'criterion': 'squared_error', 'max_features':...           0.850239
# 3   {'criterion': 'squared_error', 'max_features':...           0.829944
# 4   {'criterion': 'squared_error', 'max_features':...           0.856643
# 5   {'criterion': 'squared_error', 'max_features':...           0.858732
# 6   {'criterion': 'squared_error', 'max_features':...           0.845790
# 7   {'criterion': 'squared_error', 'max_features':...           0.858550
# 8   {'criterion': 'squared_error', 'max_features':...           0.861452
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.841950
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.851569
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.848473
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.822829
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.861189
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.859524
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.848938
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.859791
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.858222
# 18  {'criterion': 'absolute_error', 'max_features'...           0.809342
# 19  {'criterion': 'absolute_error', 'max_features'...           0.839121
# 20  {'criterion': 'absolute_error', 'max_features'...           0.840138
# 21  {'criterion': 'absolute_error', 'max_features'...           0.852740
# 22  {'criterion': 'absolute_error', 'max_features'...           0.852800
# 23  {'criterion': 'absolute_error', 'max_features'...           0.857226
# 24  {'criterion': 'absolute_error', 'max_features'...           0.850552
# 25  {'criterion': 'absolute_error', 'max_features'...           0.859801
# 26  {'criterion': 'absolute_error', 'max_features'...           0.858791
# 27  {'criterion': 'poisson', 'max_features': 'auto...           0.840418
# 28  {'criterion': 'poisson', 'max_features': 'auto...           0.850567
# 29  {'criterion': 'poisson', 'max_features': 'auto...           0.851156
# 30  {'criterion': 'poisson', 'max_features': 'sqrt...           0.840200
# 31  {'criterion': 'poisson', 'max_features': 'sqrt...           0.861886
# 32  {'criterion': 'poisson', 'max_features': 'sqrt...           0.856234
# 33  {'criterion': 'poisson', 'max_features': 'log2...           0.843282
# 34  {'criterion': 'poisson', 'max_features': 'log2...           0.854977
# 35  {'criterion': 'poisson', 'max_features': 'log2...           0.858219
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.757035           0.848204           0.823078
# 1            0.777368           0.861703           0.823885
# 2            0.772032           0.854541           0.820723
# 3            0.759794           0.846382           0.812871
# 4            0.780566           0.864745           0.827179
# 5            0.779891           0.859649           0.828614
# 6            0.762674           0.827894           0.797359
# 7            0.781510           0.857355           0.829727
# 8            0.782049           0.859725           0.831866
# 9            0.750333           0.852373           0.797229
# 10           0.769547           0.857775           0.820874
# 11           0.769369           0.855885           0.820477
# 12           0.770795           0.832297           0.818056
# 13           0.775903           0.862826           0.828925
# 14           0.780711           0.860701           0.829443
# 15           0.762658           0.832993           0.815893
# 16           0.782599           0.860398           0.827005
# 17           0.780554           0.863131           0.828986
# 18           0.756004           0.852491           0.813613
# 19           0.764369           0.847199           0.819979
# 20           0.771091           0.848424           0.822324
# 21           0.780984           0.836095           0.815711
# 22           0.776621           0.859682           0.825112
# 23           0.780890           0.859052           0.830133
# 24           0.740634           0.845343           0.816177
# 25           0.781748           0.856969           0.825748
# 26           0.781740           0.858435           0.828317
# 27           0.728067           0.862840           0.806889
# 28           0.772684           0.858505           0.816520
# 29           0.777311           0.859221           0.819354
# 30           0.757683           0.861048           0.812523
# 31           0.776741           0.860266           0.829672
# 32           0.778556           0.864097           0.831405
# 33           0.771830           0.842567           0.818515
# 34           0.779793           0.859981           0.827726
# 35           0.781180           0.861567           0.828930
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.825838         0.818455        0.032000               27
# 1            0.835391         0.829162        0.028786               17
# 2            0.838011         0.827109        0.029935               21
# 3            0.826023         0.815003        0.029604               31
# 4            0.836997         0.833226        0.029549               13
# 5            0.839978         0.833373        0.029189               12
# 6            0.822560         0.811255        0.028812               36
# 7            0.838523         0.833133        0.028065               14
# 8            0.842568         0.835532        0.028915                1
# 9            0.821100         0.812597        0.036411               34
# 10           0.836733         0.827299        0.031570               20
# 11           0.835068         0.825854        0.030717               22
# 12           0.824337         0.813663        0.021918               32
# 13           0.839638         0.833696        0.031631               10
# 14           0.839728         0.834021        0.029181                8
# 15           0.827388         0.817574        0.029449               29
# 16           0.846511         0.835261        0.028988                2
# 17           0.838925         0.833964        0.029466                9
# 18           0.826775         0.811645        0.031631               35
# 19           0.838470         0.821827        0.030082               25
# 20           0.838718         0.824139        0.027841               23
# 21           0.830187         0.823143        0.024191               24
# 22           0.843669         0.831577        0.029828               16
# 23           0.846975         0.834855        0.028870                3
# 24           0.830524         0.816646        0.039859               30
# 25           0.843224         0.833498        0.028550               11
# 26           0.846215         0.834700        0.028712                4
# 27           0.829110         0.813465        0.046358               33
# 28           0.838904         0.827436        0.030818               19
# 29           0.835389         0.828486        0.029012               18
# 30           0.836817         0.821654        0.035501               26
# 31           0.843920         0.834497        0.031183                7
# 32           0.842693         0.834597        0.030182                6
# 33           0.812771         0.817793        0.026084               28
# 34           0.841864         0.832868        0.028804               15
# 35           0.843193         0.834618        0.029137                5

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 0
# BMI: 0
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[2155.3409666]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename="finalized_model_Random_Forest_GridSearchCV.sav"
pickle.dump(grid,open(filename, 'wb'))

# %%
loaded_model=pickle.load(open("finalized_model_Random_Forest_GridSearchCV.sav", 'rb'))
result=loaded_model.predict([[0,0,0,0,0]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([2155.3409666])
