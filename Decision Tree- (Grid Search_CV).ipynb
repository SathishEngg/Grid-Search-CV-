# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent= dataset [['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset [['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= {'criterion': ['squared_error','friedman_mse','absolute_error','poisson'], 'splitter': ['best', 'random'], 'max_features' : ['auto', 'sqrt', 'log2']}

# %%
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for the best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for the best parameter{'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.265193      0.239701         0.007787        0.003991
# 1        0.068021      0.010621         0.008795        0.007540
# 2        0.028962      0.014325         0.004043        0.004607
# 3        0.019388      0.005974         0.015936        0.016243
# 4        0.021880      0.007656         0.009375        0.012499
# 5        0.030978      0.020009         0.027691        0.040843
# 6        0.064063      0.015264         0.009515        0.010394
# 7        0.079787      0.042526         0.010476        0.002960
# 8        0.022888      0.011131         0.011954        0.005397
# 9        0.019830      0.017373         0.010021        0.009073
# 10       0.019358      0.009065         0.015095        0.012029
# 11       0.017154      0.010648         0.017316        0.016605
# 12       0.609236      0.356817         0.031211        0.036527
# 13       0.317383      0.307276         0.002770        0.003489
# 14       0.068747      0.015936         0.018752        0.006253
# 15       0.064071      0.014549         0.009491        0.006374
# 16       0.084443      0.008613         0.014585        0.003248
# 17       0.075468      0.017613         0.016847        0.018570
# 18       0.897572      1.377727         0.020637        0.014189
# 19       0.344796      0.519640         0.006250        0.007655
# 20       0.031250      0.009878         0.000000        0.000000
# 21       0.033165      0.014487         0.021603        0.035909
# 22       0.018749      0.006251         0.009375        0.007654
# 23       0.018750      0.006249         0.009375        0.007654
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto           best
# 1    squared_error               auto         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               auto           best
# 7     friedman_mse               auto         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               auto           best
# 13  absolute_error               auto         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               auto           best
# 19         poisson               auto         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.724122
# 1   {'criterion': 'squared_error', 'max_features':...           0.712947
# 2   {'criterion': 'squared_error', 'max_features':...           0.712526
# 3   {'criterion': 'squared_error', 'max_features':...           0.654951
# 4   {'criterion': 'squared_error', 'max_features':...           0.728392
# 5   {'criterion': 'squared_error', 'max_features':...           0.679045
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.707504
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.670008
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.739348
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.672592
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.642357
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.664076
# 12  {'criterion': 'absolute_error', 'max_features'...           0.728542
# 13  {'criterion': 'absolute_error', 'max_features'...           0.620310
# 14  {'criterion': 'absolute_error', 'max_features'...           0.714120
# 15  {'criterion': 'absolute_error', 'max_features'...           0.789880
# 16  {'criterion': 'absolute_error', 'max_features'...           0.798966
# 17  {'criterion': 'absolute_error', 'max_features'...           0.645229
# 18  {'criterion': 'poisson', 'max_features': 'auto...           0.739219
# 19  {'criterion': 'poisson', 'max_features': 'auto...           0.679884
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.750407
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.698054
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.715592
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.723712
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.642078           0.720737           0.731500
# 1            0.637605           0.712484           0.670086
# 2            0.660241           0.682849           0.648581
# 3            0.531889           0.665967           0.664573
# 4            0.673205           0.778126           0.571110
# 5            0.559676           0.669133           0.689119
# 6            0.652533           0.725811           0.703059
# 7            0.603567           0.670358           0.713886
# 8            0.585242           0.702045           0.523566
# 9            0.597350           0.728747           0.667425
# 10           0.644402           0.670832           0.625939
# 11           0.524744           0.711555           0.670436
# 12           0.595130           0.736390           0.719379
# 13           0.610346           0.695760           0.739544
# 14           0.650802           0.729053           0.641844
# 15           0.354363           0.820935           0.736854
# 16           0.618290           0.688518           0.763944
# 17           0.628947           0.743885           0.678753
# 18           0.653872           0.736266           0.717111
# 19           0.677416           0.661749           0.724590
# 20           0.584579           0.719851           0.682442
# 21           0.604136           0.685667           0.679747
# 22           0.646372           0.708487           0.714071
# 23           0.574959           0.657163           0.614532
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.667360         0.697160        0.035733                5
# 1            0.707600         0.688144        0.029888                8
# 2            0.708934         0.682626        0.025480               10
# 3            0.629324         0.629341        0.050469               23
# 4            0.581991         0.666565        0.080718               17
# 5            0.622284         0.643852        0.047911               22
# 6            0.685170         0.694815        0.024781                7
# 7            0.713302         0.674224        0.040312               14
# 8            0.775625         0.665165        0.095397               18
# 9            0.649164         0.663056        0.042274               19
# 10           0.456611         0.608028        0.077063               24
# 11           0.652820         0.644726        0.063187               21
# 12           0.751664         0.706221        0.056547                3
# 13           0.738577         0.680908        0.055921               12
# 14           0.669025         0.680969        0.034625               11
# 15           0.633423         0.667091        0.168846               16
# 16           0.703573         0.714658        0.062658                1
# 17           0.674408         0.674245        0.039406               13
# 18           0.703467         0.709987        0.030943                2
# 19           0.736362         0.696000        0.029068                6
# 20           0.698455         0.687147        0.056110                9
# 21           0.697713         0.673063        0.035176               15
# 22           0.732709         0.703446        0.029663                4
# 23           0.701181         0.654310        0.054590               20

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 0
# BMI: 0
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1727.785]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename="finalized_model_Decision_Tree_GridSearchCV.sav"
pickle.dump(grid,open(filename, 'wb'))

# %%
loaded_model=pickle.load(open("finalized_model_Decision_Tree_GridSearchCV.sav", 'rb'))
result=loaded_model.predict([[0,0,0,0,0]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([1727.785])
